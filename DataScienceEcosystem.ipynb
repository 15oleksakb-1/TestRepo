# %% [markdown]
# ##### Exercise 2

# %% [markdown]
# # Data Science Tools and Ecosytem

# %% [markdown]
# # Data Science Tools and Ecosytem

# %% [markdown]
# ##### Exercise 3

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ##### Exercise 10

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List common libraries used for Data Science
# - Learn how to make an organized table
# - Learn how to use Python for evaluating arithmetic

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List common libraries used for Data Science
# - Learn how to make an organized table
# - Learn how to use Python for evaluating arithmetic

# %% [markdown]
# ##### Exercise 4

# %% [markdown]
# ##### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ##### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ##### Exercise 5

# %% [markdown]
# ##### Some of the commonly used libraries used by Data Scientists include:
# - Pandas
# - TensorFlow
# - ggplot2
# - Plotly

# %% [markdown]
# ##### Some of the commonly used libraries used by Data Scientists include:
# - Pandas
# - TensorFlow
# - ggplot2
# - Plotly

# %% [markdown]
# ##### Exercise 6

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | GitHub |
# | RStudio |
# | Anaconda |

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | GitHub |
# | RStudio |
# | Anaconda |

# %% [markdown]
# ##### Exercise 7

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ##### Exercise 8

# %%
# This is a simple arithmetic expression to multiply then add integers

(3*4)+5
# Out:
# 17

# %% [markdown]
# ##### Exercise 9

# %%
# This will convert 200 minutes to hours by dividing by 60

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ##### Exercise 11

# %% [markdown]
# ## Author
# ##### Brent Oleksak
